# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-28b5b4c4-bd98-4e35-8dbd-ea934a1d070c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-28b5b4c4-bd98-4e35-8dbd-ea934a1d070c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving WorldCups.csv to WorldCups.csv

# %%
data=pd.read_csv("WorldCups.csv")
df=pd.DataFrame(data)
df.head(20)
# Out:
#     Year       Country      Winner      Runners-Up        Third  \
# 0   1930       Uruguay     Uruguay       Argentina          USA
# 1   1934         Italy       Italy  Czechoslovakia      Germany
# 2   1938        France       Italy         Hungary       Brazil
# 3   1950        Brazil     Uruguay          Brazil       Sweden
# 4   1954   Switzerland  Germany FR         Hungary      Austria
# 5   1958        Sweden      Brazil          Sweden       France
# 6   1962         Chile      Brazil  Czechoslovakia        Chile
# 7   1966       England     England      Germany FR     Portugal
# 8   1970        Mexico      Brazil           Italy   Germany FR
# 9   1974       Germany  Germany FR     Netherlands       Poland
# 10  1978     Argentina   Argentina     Netherlands       Brazil
# 11  1982         Spain       Italy      Germany FR       Poland
# 12  1986        Mexico   Argentina      Germany FR       France
# 13  1990         Italy  Germany FR       Argentina        Italy
# ...

# %% [markdown]
# Q1- What country has most WorldCups?
#
#
#
# Q2-What year has most goals scored?
#
#
# Q3-Is there a relationship between yaer and number of attendant? What type of relationship is that?
#
#
#
# Q4-Is there a relationship betwen number of goals and number of taems qualified?

# %%
import seaborn as sns
sns.countplot(x=df.Winner)
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Winner'] = df['Winner'].replace(['Germany FR'],'Germany')

# %%
import seaborn as sns
sns.countplot(x=df.Winner)
plt.xticks(rotation='vertical')
plt.show()

# %%
a=df.groupby(['Winner','Year'])
a.first()
# Out:
#                      Country      Runners-Up        Third          Fourth  \
# Winner    Year
# Argentina 1978     Argentina     Netherlands       Brazil           Italy
#           1986        Mexico      Germany FR       France         Belgium
# Brazil    1958        Sweden          Sweden       France      Germany FR
#           1962         Chile  Czechoslovakia        Chile      Yugoslavia
#           1970        Mexico           Italy   Germany FR         Uruguay
#           1994           USA           Italy       Sweden        Bulgaria
#           2002   Korea/Japan         Germany       Turkey  Korea Republic
# England   1966       England      Germany FR     Portugal    Soviet Union
# France    1998        France          Brazil      Croatia     Netherlands
# Germany   1954   Switzerland         Hungary      Austria         Uruguay
#           1974       Germany     Netherlands       Poland          Brazil
# ...

# %%
x=(1,2,3,4)
print(sum(x))
# Out:
# 10

# %%
x=(1,2,3,70)
print(sum(x))
# Out:
# 76

# %%
print(min(x))
# Out:
# 1

# %%
print(max(x))
# Out:
# 70

# %%
y=[1,2,4,6]

# %%
print(sum(y
