# %%
import pandas as pd
import numpy as np
import sklearn as sk
import statsmodels.api as sm
import matplotlib.pyplot as plt
import scipy as sp
import seaborn as sns
#This will add seaborn neuaty to all graphs automaticly
sns.set()

# %%
data = pd.read_csv('/kaggle/input/automobile-dataset/Automobile.csv')
data.head()
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
# 2         plymouth satellite  18.0          8         318.0       150.0
# 3              amc rebel sst  16.0          8         304.0       150.0
# 4                ford torino  17.0          8         302.0       140.0
#
#    weight  acceleration  model_year origin
# 0    3504          12.0          70    usa
# 1    3693          11.5          70    usa
# 2    3436          11.0          70    usa
# 3    3433          12.0          70    usa
# 4    3449          10.5          70    usa

# %%
data.columns
# Out:
# Index(['name', 'mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# name            0
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
data =data.dropna(axis =0)

# %%
data.isnull().sum()
# Out:
# name            0
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
data_1 = data[['horsepower','mpg','acceleration','weight']]
data_1
# Out:
# horsepower      0
# mpg             0
# acceleration    0
# weight          0
# dtype: int64

# %%
f,axes = plt.subplots(1, 3,sharey=0,figsize=(15,3))
sns.distplot(data_1['weight'],ax=axes[0])
sns.distplot(data_1['mpg'],ax=axes[1])
sns.distplot(data_1['acceleration'],ax=axes[2])
plt.show()
# Out:
# /tmp/ipykernel_32/2986054759.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_1['weight'],ax=axes[0])
# /tmp/ipykernel_32/2986054759.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_1['mpg'],ax=axes[1])
# ...

# %%
q1= data_1['mpg'].quantile(0.99)
data_1 = data_1[data_1['mpg']<q1]

q2= data_1['weight'].quantile(0.99)
data_1 = data_1[data_1['weight']<q2]
##ignore

# %%
new = data_1[['mpg','weight','acceleration','horsepower']]
new.head()
# Out:
#     mpg  weight  acceleration  horsepower
# 0  18.0    3504          12.0       130.0
# 1  15.0    3693          11.5       165.0
# 2  18.0    3436          11.0       150.0
# 3  16.0    3433          12.0       150.0
# 4  17.0    3449          10.5       140.0

# %%
ready = new.copy()

# %%
fig,axes = plt.subplots(1,3, sharey=0,figsize=(15,3))
sns.scatterplot(data =ready,x=ready['mpg'],y=ready['horsepower'],ax=axes[0])
sns.scatterplot(data =ready,x=ready['weight'],y=ready['horsepower'],ax=axes[1])
sns.scatterplot(data =ready,x=ready['acceleration'],y=ready['horsepower'],ax=axes[2])
# Out:
# <Axes: xlabel='acceleration', ylabel='horsepower'>

# %% [markdown]
# **Checking for Multi_Colineraity among predictors**

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
var = raedy[['mpg','weight','acceleration']]

var_d =
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 2
#       1 from statsmodels.stats.outliers_influence import variance_inflation_factor
# ----> 2 var = raedy[['mpg','weight','acceleration']]
#       4 var_d = var.copy()
#
# NameError: name 'raedy' is not defined
